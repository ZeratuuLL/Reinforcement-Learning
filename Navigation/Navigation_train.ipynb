# %% [markdown]
# # Step 1. Initialize environment

# %%
from unityagents import UnityEnvironment
import numpy as np

# please do not modify the line below
env = UnityEnvironment(file_name="Banana.x86_64")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37

# %% [markdown]
# # Step 2. Import codes for training

# %%
# %load Net.py

# %%
# %load RL_Agent.py

# %%
# %load train.py

# %% [markdown]
# # Step 3. Train the agent and see the result

# %%
#This is the original DQN
agent = Agent(state_size, action_size, 0)
scores, _ = dqn()
# Out:
# Episode 100	Average Score: 1.02
# Episode 200	Average Score: 3.42
# Episode 300	Average Score: 6.06
# Episode 400	Average Score: 7.85
# Episode 500	Average Score: 9.09
# Episode 600	Average Score: 9.780
# Episode 700	Average Score: 10.41
# Episode 800	Average Score: 11.25
# Episode 900	Average Score: 12.66
# Episode 1000	Average Score: 11.89
# Episode 1100	Average Score: 12.09
# Episode 1200	Average Score: 13.05
#
# Environment solved in 1100 episodes!	Average Score: 13.05

# %%
# plot the scores
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
#This is the Dual-DQN
agent = Agent(state_size, action_size, 0, Dual = True)
scores, _ = dqn()
# Out:
# Episode 100	Average Score: 0.91
# Episode 200	Average Score: 3.75
# Episode 300	Average Score: 5.90
# Episode 400	Average Score: 8.17
# Episode 500	Average Score: 9.30
# Episode 600	Average Score: 11.53
# Episode 700	Average Score: 12.61
# Episode 800	Average Score: 11.89
# Episode 825	Average Score: 13.07
# Environment solved in 725 episodes!	Average Score: 13.07

# %%
# plot the scores
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
#This is the Prioritized DQN. This is much slower
agent = Agent(state_size, action_size, 0, prioritized = True)
scores, _ = dqn()
# Out:
# Episode 100	Average Score: 1.03
# Episode 200	Average Score: 3.43
# Episode 300	Average Score: 4.93
# Episode 400	Average Score: 7.74
# Episode 500	Average Score: 9.13
# Episode 600	Average Score: 11.05
# Episode 700	Average Score: 11.21
# Episode 800	Average Score: 12.28
# Episode 828	Average Score: 13.02
# Environment solved in 728 episodes!	Average Score: 13.02

# %%
# plot the scores
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
